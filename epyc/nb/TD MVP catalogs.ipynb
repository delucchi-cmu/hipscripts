# %%
import os
from hipscat.catalog import Catalog
from hipscat.inspection import visualize_catalog

def catalog_stats(partition_data):
    print(f'healpix orders: {partition_data["Norder"].unique()}')
    print(f'num partitions: {len(partition_data["Npix"])}')
    print(f'total rows: {partition_data["num_rows"].sum()}')
    print('------')
    print(f'min rows: {partition_data["num_rows"].min()}')
    print(f'max rows: {partition_data["num_rows"].max()}')
    print(f'object ratio: {partition_data["num_rows"].max()/partition_data["num_rows"].min()}')

# partition_data["size_on_disk"] = 0

# for index, partition in partition_data.iterrows():
#     file_name = os.path.join(
#         hipscat_dir,
#         f"Norder={int(partition['Norder'])}",
#         f"Dir={int(partition['Dir'])}",        
#         f"Npix={int(partition['Npix'])}.parquet",
#     )
#     partition_data.loc[index, "size_on_disk"] = os.path.getsize(file_name)
# partition_data = partition_data.astype(int)
# partition_info = "/astro/users/mmd11/catalogs/hst_more_partition_info.csv"
# partition_data.to_csv(partition_info, index=False)

# %%
hipscat_dir="/data3/epyc/data3/hipscat/catalogs/dr16q"
cat = Catalog(hipscat_dir)
visualize_catalog.plot_pixels(cat)
visualize_catalog.plot_points(cat)

catalog_stats(cat.get_pixels())
# Out:
# healpix orders: [0 1]
# num partitions: 21
# total rows: 750414
# ------
# min rows: 92
# max rows: 91993
# object ratio: 999.9239130434783

# %%
hipscat_dir="/data3/epyc/data3/hipscat/catalogs/dr16q_constant"
cat = Catalog.read_from_hipscat(hipscat_dir)
visualize_catalog.plot_pixels(cat)
visualize_catalog.plot_points(cat)

catalog_stats(cat.get_pixels())
# Out:
# healpix orders: [5]
# num partitions: 3657
# total rows: 750414
# ------
# min rows: 1
# max rows: 758
# object ratio: 758.0

# %%
hipscat_dir="/data3/epyc/data3/hipscat/catalogs/ztf_apr13/ztf_dr14"
cat = Catalog(hipscat_dir)
visualize_catalog.plot_pixels(cat)
visualize_catalog.plot_points(cat)

catalog_stats(cat.get_pixels())
# Out:
# healpix orders: [0]
# num partitions: 1
# total rows: 982531
# ------
# min rows: 982531
# max rows: 982531
# object ratio: 1.0

# %%
hipscat_dir="/data3/epyc/data3/hipscat/catalogs/ztf_apr18/ztf_source"
cat = Catalog(hipscat_dir)
visualize_catalog.plot_pixels(cat)
visualize_catalog.plot_points(cat)

catalog_stats(cat.get_pixels())
# Out:
# healpix orders: [0 1 2 3 4 5 6 7 8]
# num partitions: 318
# total rows: 136365892
# ------
# min rows: 14900
# max rows: 996973
# object ratio: 66.91093959731543

# %%
hipscat_dir="/data3/epyc/data3/hipscat/catalogs/ztf_apr18/ztf_dr14"
cat = Catalog(hipscat_dir)
visualize_catalog.plot_pixels(cat)
visualize_catalog.plot_points(cat)

catalog_stats(cat.get_pixels())
# Out:
# healpix orders: [1 2 3 4 5 6]
# num partitions: 2352
# total rows: 1234463018
# ------
# min rows: 4442
# max rows: 998280
# object ratio: 224.73660513282306

# %%
hipscat_dir="/epyc/data3/hipscat/catalogs/sdss/"
cat = Catalog.read_from_hipscat(catalog_path=hipscat_dir)
visualize_catalog.plot_pixels(cat)
visualize_catalog.plot_points(cat)

catalog_stats(cat.get_pixels())
# Out:
# healpix orders: [0 1 2 3 4 5 6]
# num partitions: 1032
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/lsd2env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/anaconda3/envs/lsd2env/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/lsd2env/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'num_objects'
#
# ...

# %%
hipscat_dir="/data3/epyc/data3/hipscat/catalogs/td_mvp_test/ps1_otmo_test"
cat = Catalog.read_from_hipscat(catalog_path=hipscat_dir)
visualize_catalog.plot_pixels(cat)
visualize_catalog.plot_points(cat)

catalog_stats(cat.get_pixels())
# Out:
# healpix orders: [2 5 6 7]
# num partitions: 27161
# total rows: 10560724292
# ------
# min rows: 35136
# max rows: 999839
# object ratio: 28.456255692167577

# %%
hipscat_dir="/data3/epyc/data3/hipscat/catalogs/zubercal/"
cat = Catalog.read_from_hipscat(catalog_path=hipscat_dir)
visualize_catalog.plot_pixels(cat)
visualize_catalog.plot_points(cat)

catalog_stats(cat.get_pixels())
# Out:
# healpix orders: [2 3 4 5 6 7 8 9]
# num partitions: 70853
# total rows: 646029117258
# ------
# min rows: 96
# max rows: 19999622
# object ratio: 208329.39583333334

# %%
hipscat_dir="/data3/epyc/data3/hipscat/catalogs/sdss_dr16q"
cat = Catalog.read_from_hipscat(catalog_path=hipscat_dir)
visualize_catalog.plot_pixels(cat)
visualize_catalog.plot_points(cat)

catalog_stats(cat.get_pixels())
# Out:
# healpix orders: [0 1 2 3 4 5]
# num partitions: 263
# total rows: 436701643
# ------
# min rows: 6366
# max rows: 3999165
# object ratio: 628.2068803016023
