# %%
import lsdb

catalog = lsdb.open_catalog("/data3/epyc/data3/hats/catalogs/v06/des_dr2/")

print("numRows", len(catalog))
print("numColumns", len(catalog.all_columns))
print("numPartitions", len(catalog.get_healpix_pixels()))
# Out:
# numRows 662428385
# numColumns 215
# numPartitions 1523
